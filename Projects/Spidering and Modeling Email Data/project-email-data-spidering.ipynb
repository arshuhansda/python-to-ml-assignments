# %%
import sqlite3
import time
import ssl
import urllib.request, urllib.parse, urllib.error
from urllib.parse import urljoin
from urllib.parse import urlparse
import re
from datetime import datetime, timedelta

# Not all systems have this so conditionally define parser
try:
    import dateutil.parser as parser
except:
    pass

def parsemaildate(md) :
    # See if we have dateutil
    try:
        pdate = parser.parse(tdate)
        test_at = pdate.isoformat()
        return test_at
    except:
        pass

    # Non-dateutil version - we try our best

    pieces = md.split()
    notz = " ".join(pieces[:4]).strip()

    # Try a bunch of format variations - strptime() is *lame*
    dnotz = None
    for form in [ '%d %b %Y %H:%M:%S', '%d %b %Y %H:%M:%S',
        '%d %b %Y %H:%M', '%d %b %Y %H:%M', '%d %b %y %H:%M:%S',
        '%d %b %y %H:%M:%S', '%d %b %y %H:%M', '%d %b %y %H:%M' ] :
        try:
            dnotz = datetime.strptime(notz, form)
            break
        except:
            continue

    if dnotz is None :
        # print 'Bad Date:',md
        return None

    iso = dnotz.isoformat()

    tz = "+0000"
    try:
        tz = pieces[4]
        ival = int(tz) # Only want numeric timezone values
        if tz == '-0000' : tz = '+0000'
        tzh = tz[:3]
        tzm = tz[3:]
        tz = tzh+":"+tzm
    except:
        pass

    return iso+tz

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

conn = sqlite3.connect('content.sqlite')
cur = conn.cursor()

baseurl = "http://mbox.dr-chuck.net/sakai.devel/"

cur.execute('''CREATE TABLE IF NOT EXISTS Messages
    (id INTEGER UNIQUE, email TEXT, sent_at TEXT,
     subject TEXT, headers TEXT, body TEXT)''')

# Pick up where we left off
start = None
cur.execute('SELECT max(id) FROM Messages' )
try:
    row = cur.fetchone()
    if row is None :
        start = 0
    else:
        start = row[0]
except:
    start = 0

if start is None : start = 0

many = 0
count = 0
fail = 0
while True:
    if ( many < 1 ) :
        conn.commit()
        sval = input('How many messages:')
        if ( len(sval) < 1 ) : break
        many = int(sval)

    start = start + 1
    cur.execute('SELECT id FROM Messages WHERE id=?', (start,) )
    try:
        row = cur.fetchone()
        if row is not None : continue
    except:
        row = None

    many = many - 1
    url = baseurl + str(start) + '/' + str(start + 1)

    text = "None"
    try:
        # Open with a timeout of 30 seconds
        document = urllib.request.urlopen(url, None, 30, context=ctx)
        text = document.read().decode()
        if document.getcode() != 200 :
            print("Error code=",document.getcode(), url)
            break
    except KeyboardInterrupt:
        print('')
        print('Program interrupted by user...')
        break
    except Exception as e:
        print("Unable to retrieve or parse page",url)
        print("Error",e)
        fail = fail + 1
        if fail > 5 : break
        continue

    print(url,len(text))
    count = count + 1

    if not text.startswith("From "):
        print(text)
        print("Did not find From ")
        fail = fail + 1
        if fail > 5 : break
        continue

    pos = text.find("\n\n")
    if pos > 0 :
        hdr = text[:pos]
        body = text[pos+2:]
    else:
        print(text)
        print("Could not find break between headers and body")
        fail = fail + 1
        if fail > 5 : break
        continue

    email = None
    x = re.findall('\nFrom: .* <(\S+@\S+)>\n', hdr)
    if len(x) == 1 :
        email = x[0];
        email = email.strip().lower()
        email = email.replace("<","")
    else:
        x = re.findall('\nFrom: (\S+@\S+)\n', hdr)
        if len(x) == 1 :
            email = x[0];
            email = email.strip().lower()
            email = email.replace("<","")

    date = None
    y = re.findall('\Date: .*, (.*)\n', hdr)
    if len(y) == 1 :
        tdate = y[0]
        tdate = tdate[:26]
        try:
            sent_at = parsemaildate(tdate)
        except:
            print(text)
            print("Parse fail",tdate)
            fail = fail + 1
            if fail > 5 : break
            continue

    subject = None
    z = re.findall('\Subject: (.*)\n', hdr)
    if len(z) == 1 : subject = z[0].strip().lower();

    # Reset the fail counter
    fail = 0
    print("   ",email,sent_at,subject)
    cur.execute('''INSERT OR IGNORE INTO Messages (id, email, sent_at, subject, headers, body)
        VALUES ( ?, ?, ?, ?, ?, ? )''', ( start, email, sent_at, subject, hdr, body))
    if count % 50 == 0 : conn.commit()
    if count % 100 == 0 : time.sleep(1)

conn.commit()
cur.close()
# Out:
# How many messages:100
# http://mbox.dr-chuck.net/sakai.devel/59643/59644 17553
#     matthew@longsight.com 2015-03-20T16:27:12-04:00 re: [building sakai] sakai 10 bulding error
# http://mbox.dr-chuck.net/sakai.devel/59644/59645 13128
#     alberto.olivamolina@gmail.com 2015-03-20T16:36:12+01:00 re: [building sakai] sakai 10 bulding error
# http://mbox.dr-chuck.net/sakai.devel/59645/59646 7557
#     eric.duquenoy@univ-littoral.fr 2015-03-20T16:52:24+01:00 [building sakai] lti and sakai groups (or sections)
# http://mbox.dr-chuck.net/sakai.devel/59646/59647 1
#
#
# Did not find From
# http://mbox.dr-chuck.net/sakai.devel/59647/59648 9467
#     csev@umich.edu 2015-03-20T23:04:53-04:00 re: [building sakai] lti and sakai groups (or sections)
# http://mbox.dr-chuck.net/sakai.devel/59648/59649 11727
#     matthew@longsight.com 2015-03-20T23:12:47-04:00 re: [building sakai] lti and sakai groups (or sections)
# http://mbox.dr-chuck.net/sakai.devel/59649/59650 5916
#     blshrestha@mum.edu 2015-03-20T23:42:44-05:00 [using sakai] bulk picture import
# http://mbox.dr-chuck.net/sakai.devel/59650/59651 1
#
#
# Did not find From
# http://mbox.dr-chuck.net/sakai.devel/59651/59652 13529
#     steve.swinsburg@gmail.com 2015-03-21T07:22:35+11:00 re: [building sakai] sakai 10 bulding error
# http://mbox.dr-chuck.net/sakai.devel/59652/59653 25324
#     alberto.olivamolina@gmail.com 2015-03-21T11:14:44+01:00 re: [building sakai] sakai 10 bulding error
# http://mbox.dr-chuck.net/sakai.devel/59653/59654 6468
#     steve.swinsburg@gmail.com 2015-03-23T00:25:46+11:00 re: [building sakai] bulk picture import
# http://mbox.dr-chuck.net/sakai.devel/59654/59655 4244
#     csev@umich.edu 2015-03-23T08:46:02-04:00 [building sakai] the pda portal, xsl portal,
# http://mbox.dr-chuck.net/sakai.devel/59655/59656 11360
#     csev@umich.edu 2015-03-23T09:29:01-04:00 re: [building sakai] the pda portal, xsl portal,
#     alaanizar@iihem.ac.ma 2015-03-24T11:17:14+00:00 re: [building sakai] userid with no spaces nor special characters
# http://mbox.dr-chuck.net/sakai.devel/59673/59674 26526
#     mcarro@entornosdeformacion.com 2015-03-24T12:13:27+01:00 re: [building sakai] userid with no spaces nor special characters
# http://mbox.dr-chuck.net/sakai.devel/59674/59675 21927
#     neal.caidin@apereo.org 2015-03-24T12:40:09-04:00 re: [building sakai] the pda portal, xsl portal,
# http://mbox.dr-chuck.net/sakai.devel/59675/59676 32264
#     mcarro@entornosdeformacion.com 2015-03-24T14:07:35+01:00 re: [building sakai] userid with no spaces nor special characters
# http://mbox.dr-chuck.net/sakai.devel/59676/59677 21494
#     davidwafula.wanyonyi@wits.ac.za 2015-03-24T14:22:20+00:00 re: [building sakai] forums slow in 10.2
# http://mbox.dr-chuck.net/sakai.devel/59677/59678 9368
#     hornersa@plu.edu 2015-03-24T17:06:32-07:00 [building sakai] problem with ckeditor server browser (sakai 10.4)
# http://mbox.dr-chuck.net/sakai.devel/59678/59679 11793
#     wilsonk@mail.amc.edu 2015-03-24T17:07:42+00:00 [building sakai] disabling some features in profile2
# http://mbox.dr-chuck.net/sakai.devel/59679/59680 18620
#     adam.marshall@it.ox.ac.uk 2015-03-24T17:20:23+00:00 re: [building sakai] disabling some features in profile2
# http://mbox.dr-chuck.net/sakai.devel/59680/59681 13924
#     blshrestha@mum.edu 2015-03-25T02:00:09-05:00 re: [building sakai] bulk picture import
# http://mbox.dr-chuck.net/sakai.devel/59681/59682 22344
#     blshrestha@mum.edu 2015-03-25T15:57:05-05:00 re: [building sakai] disabling some features in profile2
# http://mbox.dr-chuck.net/sakai.devel/59682/59683 14214
#     sakai-core-team@collab.sakaiproject.org 2015-03-25T16:25:07+00:00 [building sakai] sakai core team call, thursday, 2015-03-26,
# http://mbox.dr-chuck.net/sakai.devel/59683/59684 4526
#     bjones86@uwo.ca 2015-03-25T17:13:02-04:00 re: [building sakai] help
# http://mbox.dr-chuck.net/sakai.devel/59684/59685 32371
#     steve.swinsburg@gmail.com 2015-03-25T17:26:41+11:00 re: [building sakai] userid with no spaces nor special characters
# http://mbox.dr-chuck.net/sakai.devel/59685/59686 7899
#     chimata@e-limu.co.za> 2015-03-25T23:06:24+02:00 [building sakai] help
# http://mbox.dr-chuck.net/sakai.devel/59686/59687 12000
#     steve.swinsburg@gmail.com 2015-03-26T07:38:13+11:00 re: [building sakai] disabling some features in profile2
# http://mbox.dr-chuck.net/sakai.devel/59687/59688 15831
#     raulsv@um.es 2015-03-26T09:10:56+01:00 re: [building sakai] the use of curly brackets in the fill in the
# http://mbox.dr-chuck.net/sakai.devel/59688/59689 16230
#     steve.swinsburg@gmail.com 2015-03-26T09:10:57+11:00 re: [building sakai] disabling some features in profile2
# http://mbox.dr-chuck.net/sakai.devel/59689/59690 6440
#     willkara@oit.rutgers.edu 2015-03-26T09:24:10-04:00 [building sakai] availability of sakai 10.x tags and future
#     csev@umich.edu 2015-03-28T22:47:19-04:00 re: [building sakai] lti content extension
# http://mbox.dr-chuck.net/sakai.devel/59708/59709 9132
#     diego.delblanco.sakai@gmail.com 2015-03-30T07:37:22-07:00 re: [building sakai] lti content extension
# http://mbox.dr-chuck.net/sakai.devel/59709/59710 13027
#     jeffrey.miller.ctr@usuhs.edu 2015-03-30T08:01:09-04:00 [building sakai] ani sakai 10.2.1 build failure
# http://mbox.dr-chuck.net/sakai.devel/59710/59711 43223
#     mcarro@entornosdeformacion.com 2015-03-30T08:45:52+02:00 re: [building sakai]
# http://mbox.dr-chuck.net/sakai.devel/59711/59712 8566
#     matthew@longsight.com 2015-03-30T08:52:13-04:00 re: [building sakai] site stats for lessons tool and lti tools
# http://mbox.dr-chuck.net/sakai.devel/59712/59713 16544
#     neal.caidin@apereo.org 2015-03-30T10:34:43-04:00 re: [building sakai] ani sakai 10.2.1 build failure
# http://mbox.dr-chuck.net/sakai.devel/59713/59714 61035
#     matthew@longsight.com 2015-03-30T10:53:16-04:00 re: [building sakai]
# http://mbox.dr-chuck.net/sakai.devel/59714/59715 3670
#     adam.marshall@it.ox.ac.uk 2015-03-30T12:29:02+00:00 [using sakai] site stats for lessons tool and lti tools
# http://mbox.dr-chuck.net/sakai.devel/59715/59716 62959
#     mcarro@entornosdeformacion.com 2015-03-30T13:15:39+02:00 re: [building sakai]
# http://mbox.dr-chuck.net/sakai.devel/59716/59717 91858
#     mcarro@entornosdeformacion.com 2015-03-30T17:39:43+02:00 re: [building sakai]
# http://mbox.dr-chuck.net/sakai.devel/59717/59718 6837
#     enietzel@anisakai.com 2015-03-30T19:25:21-04:00 re: [building sakai] ani sakai 10.2.1 build failure
# http://mbox.dr-chuck.net/sakai.devel/59718/59719 5395
#     neal.caidin@apereo.org 2015-03-31T08:02:57-04:00 [building sakai] today's sakai core meeting,
# http://mbox.dr-chuck.net/sakai.devel/59719/59720 7517
#     neal.caidin-wgvhjocuptadnm+yrofe0a@public.gmane.org 2015-03-31T08:20:48-04:00 re: [wg: sakai qa] sakai qa meeting, tuesday,
# http://mbox.dr-chuck.net/sakai.devel/59720/59721 1
#
#
# Did not find From
# http://mbox.dr-chuck.net/sakai.devel/59721/59722 4766
#     kchan@hawaii.edu 2015-03-31T09:40:07-10:00 [building sakai] sakai google docs, google apps
# http://mbox.dr-chuck.net/sakai.devel/59722/59723 3239
#     mna@harf.com 2015-03-31T11:33:57+02:00 [building sakai] sakai 10.4 and blackboard integration
# http://mbox.dr-chuck.net/sakai.devel/59723/59724 18082
#     rlong@unicon.net 2015-03-31T12:13:34-07:00 re: [building sakai] import blackboard questions/test pools
# http://mbox.dr-chuck.net/sakai.devel/59724/59725 7338
#     mna@harf.com 2015-03-31T12:40:12+02:00 re: [building sakai] sakai 10.4 and blackboard integration
# http://mbox.dr-chuck.net/sakai.devel/59725/59726 28457
#     mcarro@entornosdeformacion.com 2015-03-31T12:53:23+02:00 re: [building sakai] sakai 10.4 and blackboard integration
# http://mbox.dr-chuck.net/sakai.devel/59726/59727 28658
#     mna@harf.com 2015-03-31T13:36:26+02:00 re: [building sakai] sakai 10.4 and blackboard integration
# http://mbox.dr-chuck.net/sakai.devel/59727/59728 6430
#     raymond.naseef@gmail.com 2015-03-31T18:56:30-04:00 re: [building sakai] sakai google docs, google apps
# http://mbox.dr-chuck.net/sakai.devel/59728/59729 11338
#     kevin.d.murphy@cengage.com 2015-03-31T19:07:16+00:00 [building sakai] import blackboard questions/test pools
# http://mbox.dr-chuck.net/sakai.devel/59729/59730 5302
#     steve.swinsburg@gmail.com 2015-03-31T21:36:33+11:00 re: [building sakai] sakai 10.4 and blackboard integration
# http://mbox.dr-chuck.net/sakai.devel/59730/59731 5111
#     mark@alienresident.net 2015-03-31T22:42:09-04:00 re: [building sakai] morpheus style sampler
# http://mbox.dr-chuck.net/sakai.devel/59731/59732 20548
#     kevin.d.murphy@cengage.com 2015-03-31T23:44:43+00:00 re: [building sakai] import blackboard questions/test pools
# http://mbox.dr-chuck.net/sakai.devel/59732/59733 6002
#     neal.caidin@apereo.org 2015-04-01T07:45:31-04:00 [building sakai] new sakai architecture
# http://mbox.dr-chuck.net/sakai.devel/59733/59734 4827
#     steve.swinsburg@gmail.com 2015-04-01T08:13:37+11:00 [building sakai] morpheus style sampler
# http://mbox.dr-chuck.net/sakai.devel/59734/59735 26538
#     rlong@unicon.net 2015-04-01T08:53:40-07:00 re: [building sakai] new sakai architecture
# http://mbox.dr-chuck.net/sakai.devel/59735/59736 28169
#     neal.caidin@apereo.org 2015-04-01T08:58:47-04:00 re: [building sakai] new sakai architecture
# http://mbox.dr-chuck.net/sakai.devel/59736/59737 26056
#     rlong@unicon.net 2015-04-01T08:58:59-07:00 re: [building sakai] import blackboard questions/test pools
# http://mbox.dr-chuck.net/sakai.devel/59737/59738 38011
#     bbailla2@uwo.ca 2015-04-01T10:32:59-04:00 re: [building sakai] new sakai architecture
# http://mbox.dr-chuck.net/sakai.devel/59738/59739 22762
#     neal.caidin-wgvhjocuptadnm+yrofe0a@public.gmane.org 2015-04-01T12:42:13-04:00 re: [wg: sakai qa] sakai core team call, thursday, 2015-04-02,
# http://mbox.dr-chuck.net/sakai.devel/59739/59740 36678
#     willkara@oit.rutgers.edu 2015-04-01T12:52:35-04:00 re: [building sakai] new sakai architecture
# http://mbox.dr-chuck.net/sakai.devel/59740/59741 29217
#     adrian.r.fish@gmail.com 2015-04-01T14:03:44+01:00 re: [building sakai] new sakai architecture
# http://mbox.dr-chuck.net/sakai.devel/59741/59742 36252
#     willkara@oit.rutgers.edu 2015-04-01T14:10:43-04:00 re: [building sakai] new sakai architecture
# http://mbox.dr-chuck.net/sakai.devel/59742/59743 27129
#     mcarro@entornosdeformacion.com 2015-04-01T14:28:06+02:00 re: [building sakai] new sakai architecture
# How many messages:
