# %% [markdown]
# ### Creating a spider which crawls from one page, goes to the links in the pages and then crwals over each link page it got

# %%
import sqlite3
import urllib.error
import ssl
from urllib.parse import urljoin
from urllib.parse import urlparse
from urllib.request import urlopen
from bs4 import BeautifulSoup

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

conn = sqlite3.connect('spider-new-url.sqlite')
cur = conn.cursor()

cur.execute('''CREATE TABLE IF NOT EXISTS Pages
    (id INTEGER PRIMARY KEY, url TEXT UNIQUE, html TEXT,
     error INTEGER, old_rank REAL, new_rank REAL)''')

cur.execute('''CREATE TABLE IF NOT EXISTS Links
    (from_id INTEGER, to_id INTEGER, UNIQUE(from_id, to_id))''')

cur.execute('''CREATE TABLE IF NOT EXISTS Webs (url TEXT UNIQUE)''')

cur.execute('SELECT id,url FROM Pages WHERE html is NULL and error is NULL ORDER BY RANDOM() LIMIT 1')

row = cur.fetchone()
if row is not None:
    print("Restarting existing crawl.  Remove spider-wiki.sqlite to start a fresh crawl.")
else :
    starturl = input('Enter web url or enter: ')
    if ( len(starturl) < 1 ) : starturl = 'https://news.google.com/'
    if ( starturl.endswith('/') ) : starturl = starturl[:-1]
    web = starturl
    if ( starturl.endswith('.htm') or starturl.endswith('.html') ) :
        pos = starturl.rfind('/')
        web = starturl[:pos]

    if ( len(web) > 1 ) :
        cur.execute('INSERT OR IGNORE INTO Webs (url) VALUES ( ? )', ( web, ) )
        cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( starturl, ) )
        conn.commit()

cur.execute('''SELECT url FROM Webs''')

webs = list()
for row in cur:
    webs.append(str(row[0]))

print(webs)

many = 0
while True:
    if ( many < 1 ) :
        sval = input('How many pages:')
        if ( len(sval) < 1 ) : break
        many = int(sval)
    many = many - 1

    cur.execute('SELECT id,url FROM Pages WHERE html is NULL and error is NULL ORDER BY RANDOM() LIMIT 1')
    try:
        row = cur.fetchone()
        # print row
        fromid = row[0]
        url = row[1]
    except Exception as e:
        print(e)
        print('No unretrieved HTML pages found')
        many = 0
        break

    print(fromid, url, end=' ')

    # If we are retrieving this page, there should be no links from it
    cur.execute('DELETE from Links WHERE from_id=?', (fromid, ) )
    try:
        document = urlopen(url, context=ctx)

        html = document.read()
        if document.getcode() != 200 :
            print("Error on page: ",document.getcode())
            cur.execute('UPDATE Pages SET error=? WHERE url=?', (document.getcode(), url) )

        if 'text/html' != document.info().get_content_type() :
            print("Ignore non text/html page")
            cur.execute('DELETE FROM Pages WHERE url=?', ( url, ) )
            conn.commit()
            continue

        print('('+str(len(html))+')', end=' ')

        soup = BeautifulSoup(html, "html.parser")
    except KeyboardInterrupt:
        print('')
        print('Program interrupted by user...')
        break
    except:
        print("Unable to retrieve or parse page")
        cur.execute('UPDATE Pages SET error=-1 WHERE url=?', (url, ) )
        conn.commit()
        continue

    cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( url, ) )
    cur.execute('UPDATE Pages SET html=? WHERE url=?', (memoryview(html), url ) )
    conn.commit()

    # Retrieve all of the anchor tags
    tags = soup('a')
    count = 0
    for tag in tags:
        href = tag.get('href', None)
        if ( href is None ) : continue
        # Resolve relative references like href="/contact"
        up = urlparse(href)
        if ( len(up.scheme) < 1 ) :
            href = urljoin(url, href)
        ipos = href.find('#')
        if ( ipos > 1 ) : href = href[:ipos]
        if ( href.endswith('.png') or href.endswith('.jpg') or href.endswith('.gif') ) : continue
        if ( href.endswith('/') ) : href = href[:-1]
        # print href
        if ( len(href) < 1 ) : continue

		# Check if the URL is in any of the webs
        found = False
        for web in webs:
            if ( href.startswith(web) ) :
                found = True
                break
        if not found : continue

        cur.execute('INSERT OR IGNORE INTO Pages (url, html, new_rank) VALUES ( ?, NULL, 1.0 )', ( href, ) )
        count = count + 1
        conn.commit()

        cur.execute('SELECT id FROM Pages WHERE url=? LIMIT 1', ( href, ))
        try:
            row = cur.fetchone()
            toid = row[0]
        except:
            print('Could not retrieve id')
            continue
        # print fromid, toid
        cur.execute('INSERT OR IGNORE INTO Links (from_id, to_id) VALUES ( ?, ? )', ( fromid, toid ) )


    print(count)
    
cur.close()
# Out:
# Enter web url or enter:
# ['https://news.google.com']
# How many pages:100
# 1 https://news.google.com (1346561) 129
# 2 https://news.google.com/?hl=en-IN&gl=IN&ceid=IN%3Aen (1338445) 129
# 3 https://news.google.com/?tab=nn (1338543) 129
# 71 https://news.google.com/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE53T0RVU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1723479) 293
# 143 https://news.google.com/topics/articles/CAIiEFwEHbghgzmDp64ximpWJtAqGQgEKhAIACoHCAowsLXdCjCm3dEBMNS-swY?hl=en-IN&gl=IN&ceid=IN%3Aen (1338472) 129
# 194 https://news.google.com/topics/articles/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1346532) 129
# 18 https://news.google.com/articles/CAIiENVz4o18nfi9UNy8o1vSlBEqGQgEKhAIACoHCAowj8n_CjDIrfkCMNWczwY?hl=en-IN&gl=IN&ceid=IN%3Aen (833106) 14
# 146 https://news.google.com/topics/articles/CAIiENLiDXjf9RUsmpk-tj0Ixx4qGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen (1346511) 129
# 237 https://news.google.com/topics/articles/articles/CCAiC29vZFRtLUJDUTdJmAEB?hl=en-IN&gl=IN&ceid=IN%3Aen (1338485) 129
# 316 https://news.google.com/topics/articles/topics/publications/CAAqBwgKMOaqjQsw-KufAw?hl=en-IN&gl=IN&ceid=IN%3Aen (1340809) 130
# 84 https://news.google.com/topics/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1340794) 130
# 206 https://news.google.com/topics/articles/articles/CAIiEOcIjNvslAoO6_4tze8yjpgqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen (1332699) 130
# 532 https://news.google.com/topics/topics/stories/CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWpTeVpETmtZQU1FZklKckg4S2liRDVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1340796) 130
# 321 https://news.google.com/topics/articles/topics/articles/CBMihgFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvaW5kaWFuLWdvdmVybm1lbnQtaGFzLW5vdC1hcHByb3ZlZC1waGFybWFjaXN0cy10by1ydW4tY2xpbmljcy1pbi1jb3VudHJ5LTE3NTUzMjAtMjAyMS0wMS0wMtIBAA?hl=en-IN&gl=IN&ceid=IN%3Aen (1332696) 130
# 355 https://news.google.com/topics/articles/articles/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1332709) 130
# 99 https://news.google.com/topics/publications/CAAqBwgKMIm_jQsw2sCfAw?hl=en-IN&gl=IN&ceid=IN%3Aen (1340771) 130
# 113 https://news.google.?hl=en-IN&gl=IN&ceid=IN%3Aen (1332358) 130
# 712 https://news.google.com/topics/articles/topics/articles/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNR1JxWjNRU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1340442) 130
# 603 https://news.google.com/topics/topics/stories/articles/CAIiEFDwXhL5EdzGhmET9c6XM24qGQgEKhAIACoHCAownZiCCzDY7_4CMKTw8gU?hl=en-IN&gl=IN&ceid=IN%3Aen (1332366) 130
# 856 https://news.google.com/topics/publications/articles/CBMieGh0dHBzOi8vZmFjdGx5LmluL2ltYWdlLW9mLWNubi1yZXBvcnQtc3RhdGluZy12YWNjaW5lLWFkbWluaXN0ZXJlZC1jb3ZpZC0xOS1wYXRpZW50cy1lYXRpbmctb3RoZXJzLWlzLWRpZ2l0YWxseS1jcmVhdGVkL9IBAA?hl=en-IN&gl=IN&ceid=IN%3Aen (1332376) 130
# 767 https://news.google.com/topics/articles/articles/topics/publications/CAAqBwgKMIm_jQsw2sCfAw?hl=en-IN&gl=IN&ceid=IN%3Aen (1340471) 130
# 348 https://news.google.com/topics/articles/articles/?hl=en-IN&gl=IN&ceid=IN%3Aen (1340431) 130
# 770 https://news.google.com/topics/articles/articles/topics/articles/CAIiEJpcxpTF6ROR7UH7-UthvKwqGQgEKhAIACoHCAow7pf_CjDdlfgCMP2F6gU?hl=en-IN&gl=IN&ceid=IN%3Aen (1332360) 130
# 446 https://news.google....?hl=en-IN&gl=IN&ceid=IN%3Aen (1332892) 130
# 346 https://news.google.com/articles/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp0Y1RjU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1332882) 130
# 187 https://news.google.com/topics/articles/CAIiEP9DJMkQErTc2zy1hokbQ6MqGQgEKhAIACoHCAownZiCCzDY7_4CMKTw8gU?hl=en-IN&gl=IN&ceid=IN%3Aen (1340934) 130
# 883 https://news.google.com/topics/articles/topics/articles/topics/publications/CAAqBwgKMM6y_Qowwu70Ag?hl=en-IN&gl=IN&ceid=IN%3Aen (1332912) 130
# 809 https://news.google.com/topics/publications/publications/CAAqBwgKMI_J_wowyK35Ag?hl=en-IN&gl=IN&ceid=IN%3Aen (1332895) 130
# 1348 https://news.google.com/articles/topics/articles/CAIiEJe67OxPYOF2mtSOz3EWC8EqGQgEKhAIACoHCAowyo-HCzD-tIUDMKfilgY?hl=en-IN&gl=IN&ceid=IN%3Aen (1332867) 130
# 676 https://news.google.com/topics/articles/topics/articles/articles/CAIiEB8C4PheRan5VNGuUswdWccqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen (1333776) 130
# 1666 https://news.google.com/topics/articles/topics/articles/articles/articles/CAIiEOFVNzncgXr8D3AjlHGKWfEqGQgEKhAIACoHCAowzrL9CjDC7vQCMK2y1gU?hl=en-IN&gl=IN&ceid=IN%3Aen (1333842) 130
# 100 https://news.google.com/topics/stories/CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWpnc3VfTGtZQU1FWHd6bDR5bWZUQmtLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1333796) 130
# 414 https://news.google.com/topics/articles/articles/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNRE5tT0hkMEVnSmxiaWdBUAE?hl=en-IN&gl=IN&ceid=IN%3Aen (1333807) 130
# 840 https://news.google.com/topics/publications/articles/CAIiECMRZQQavoW5Svk37cX6OWUqGQgEKhAIACoHCAowib-NCzDawJ8DMIa_pwY?hl=en-IN&gl=IN&ceid=IN%3Aen (1333748) 130
# 1733 https://news.google.com/topics/articles/topics/articles/articles/articles/publications/CAAqBwgKMIm_jQsw2sCfAw?hl=en-IN&gl=IN&ceid=IN%3Aen (1333800) 130
# 1870 https://news.google.com/topics/articles/topics/articles/articles/articles/publications/articles/CAIiEGa57_4t7hGw8PXPwgVVFf0qFggEKg4IACoGCAoww7k_MMevCDDpywE?hl=en-IN&gl=IN&ceid=IN%3Aen (1341886) 130
# 415 https://news.google.com/topics/articles/articles/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNR1JxWjNRU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1341906) 130
# 344 https://news.google.com/articles/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNREpxYW5RU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1341804) 130
# 408 https://news.google.com/topics/articles/articles/articles/CBMiSWh0dHBzOi8vd3d3LmJvb21saXZlLmluL3dvcmxkL21pa2UtcGVuY2UtY292aWQtMTktdmFjY2luZS1mYWtlLW5ld3MtMTEzMznSAQA?hl=en-IN&gl=IN&ceid=IN%3Aen (1333763) 130
# 705 https://news.google.com/topics/articles/topics/articles/articles/CBMiSWh0dHBzOi8vd3d3LmJvb21saXZlLmluL3dvcmxkL21pa2UtcGVuY2UtY292aWQtMTktdmFjY2luZS1mYWtlLW5ld3MtMTEzMznSAQA?hl=en-IN&gl=IN&ceid=IN%3Aen (1341852) 130
# 341 https://news.google.com/articles/topics/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE?hl=en-IN&gl=IN&ceid=IN%3Aen (1341850) 130
# 941 https://news.google.com/topics/articles/topics/articles/topics/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNREV6TldSeUVnSmxiaWdBUAE?hl=en-IN&gl=IN&ceid=IN%3Aen (1333788) 130
# 1177 https://news.google.com/topics/articles/articles/topics/articles/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNR3QwTlRFU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1341921) 130
# 1309 https://news.google.com/topics/articles/topics/publications/articles/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE53T0RVU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1333847) 130
# 1744 https://news.google.com/topics/articles/topics/articles/articles/articles/articles/CBMihgFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvaW5kaWFuLWdvdmVybm1lbnQtaGFzLW5vdC1hcHByb3ZlZC1waGFybWFjaXN0cy10by1ydW4tY2xpbmljcy1pbi1jb3VudHJ5LTE3NTUzMjAtMjAyMS0wMS0wMtIBAA?hl=en-IN&gl=IN&ceid=IN%3Aen (1341917) 130
# 933 https://news.google.com/topics/articles/topics/articles/topics/topics/CAAqJAgKIh5DQkFTRUFvS0wyMHZNRFo2Y2pCbWJCSUNaVzRvQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1341887) 130
# 393 https://news.google.com/topics/articles/articles/articles/CCAiC0xSVU1BUHZLVVh3mAEB?hl=en-IN&gl=IN&ceid=IN%3Aen (1333858) 130
# 1916 https://news.google.com/topics/articles/topics/articles/articles/articles/publications/articles/?hl=en-IN&gl=IN&ceid=IN%3Aen (1333813) 130
# 10 https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (3505788) 784
# 584 https://news.google.com/topics/topics/stories/articles/CAIiEB7ha0OobjT3hoeX1vQSmwMqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen (1333826) 130
# 742 https://news.google.com/topics/articles/articles/topics/articles/CAIiEGSkLSkkLtjjC9k25Bza41oqGQgEKhAIACoHCAowj8n_CjDIrfkCMJWZ2AY?hl=en-IN&gl=IN&ceid=IN%3Aen (1341931) 130
# 525 https://news.google.com/topics/topics/articles/CAIiEPGWktwDn17tc6m9jUfv23kqGQgEKhAIACoHCAow55veCjDzvdUBMIPh5gU?hl=en-IN&gl=IN&ceid=IN%3Aen (1341971) 130
# 773 https://news.google.com/topics/articles/articles/topics/publications/CAAqBwgKMOaqjQsw-KufAw?hl=en-IN&gl=IN&ceid=IN%3Aen (1341929) 130
# 2128 https://news.google.com/topics/articles/topics/articles/topics/topics/articles/CBMihQFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvZmFjdC1jaGVjay1wbS1tb2RpLW5ldmVyLXNhaWQtdmFqcGF5ZWUtc3RhcnRlZC10aGUtZmlyc3QtbWV0cm8taW4taW5kaWEtMTc1NDYwNC0yMDIwLTEyLTMw0gEA?hl=en-IN&gl=IN&ceid=IN%3Aen (1340726) 130
# 1266 https://news.google.com/topics/articles/topics/publications/articles/articles/CAIiELhBWSd1wS4RRjIWZqRiFH4qFggEKg4IACoGCAoww7k_MMevCDDpywE?hl=en-IN&gl=IN&ceid=IN%3Aen (1295884) 120
# 2631 https://news.google.com/topics/stories/CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWlhNE1qTWtZQU1FZXpYTzdiT3M1LXNLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1295923) 120
# 928 https://news.google.com/topics/articles/topics/articles/topics/articles/CBMihgFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvaW5kaWFuLWdvdmVybm1lbnQtaGFzLW5vdC1hcHByb3ZlZC1waGFybWFjaXN0cy10by1ydW4tY2xpbmljcy1pbi1jb3VudHJ5LTE3NTUzMjAtMjAyMS0wMS0wMtIBAA?hl=en-IN&gl=IN&ceid=IN%3Aen (1303979) 120
# 2538 https://news.google.com/topics/articles/CBMiS2h0dHBzOi8vd3d3LnhkYS1kZXZlbG9wZXJzLmNvbS9vbmVwbHVzLW5vcmQtbjEwLTVnLXVuYnJpY2stbXNtZG93bmxvYWR0b29sL9IBT2h0dHBzOi8vd3d3LnhkYS1kZXZlbG9wZXJzLmNvbS9vbmVwbHVzLW5vcmQtbjEwLTVnLXVuYnJpY2stbXNtZG93bmxvYWR0b29sL2FtcC8?hl=en-IN&gl=IN&ceid=IN%3Aen (1295890) 120
# 2112 https://news.google.com/topics/articles/topics/articles/topics/topics/articles/CCAiC0xSVU1BUHZLVVh3mAEB?hl=en-IN&gl=IN&ceid=IN%3Aen (1295898) 120
# 2828 https://news.google.com/topics/articles/topics/articles/topics/topics/articles/articles/CAIiEGSkLSkkLtjjC9k25Bza41oqGQgEKhAIACoHCAowj8n_CjDIrfkCMJWZ2AY?hl=en-IN&gl=IN&ceid=IN%3Aen (1303966) 120
# 1516 https://news.google.com/topics/publications/publications/articles/CAIiEEwFTGEbhNWCDycyN9_a8poqGQgEKhAIACoHCAow5qqNCzD4q58DMMPepwY?hl=en-IN&gl=IN&ceid=IN%3Aen (1295869) 120
# 195 https://news.google.com/topics/articles/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1331197) 130
# 2009 https://news.google.com/topics/articles/articles/articles/publications/CAAqBwgKMI_J_wowyK35Ag?hl=en-IN&gl=IN&ceid=IN%3Aen (1331175) 130
# 2798 https://news.google.com/topics/topics/articles/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE53T0RVU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1331199) 130
# 162 https://news.google.com/topics/articles/CAIiEAn59Guq4mCRKEKBir4OozYqGQgEKhAIACoHCAowr6n9CjCr4PQCMOTdpQY?hl=en-IN&gl=IN&ceid=IN%3Aen (1323113) 130
# 1645 https://news.google.com/topics/articles/topics/articles/articles/articles/CAIiEJe67OxPYOF2mtSOz3EWC8EqGQgEKhAIACoHCAowyo-HCzD-tIUDMKfilgY?hl=en-IN&gl=IN&ceid=IN%3Aen (1323127) 130
# 1801 https://news.google.?hl=en-IN&gl=IN&ceid=IN%3Aen (1331776) 130
# 1330 https://news.google.com/articles/topics/publications/CAAqBwgKMI_J_wowyK35Ag?hl=en-IN&gl=IN&ceid=IN%3Aen (1331778) 130
# 1988 https://news.google.com/topics/articles/topics/articles/articles/articles/publications/articles/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNREV6TldOM0VnSmxiaWdBUAE?hl=en-IN&gl=IN&ceid=IN%3Aen (1331800) 130
# 1884 https://news.google.?hl=en-IN&gl=IN&ceid=IN%3Aen (1331795) 130
# 3288 https://news.google.com/topics/topics/articles/topics/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp0Y1RjU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1331742) 130
# 403 https://news.google.com/topics/articles/articles/articles/CAIiEOFVNzncgXr8D3AjlHGKWfEqGQgEKhAIACoHCAowzrL9CjDC7vQCMK2y1gU?hl=en-IN&gl=IN&ceid=IN%3Aen (1323655) 130
# 1424 https://news.google.com/topics/articles/topics/articles/topics/publications/publications/CAAqBwgKMMqPhwsw_rSFAw?hl=en-IN&gl=IN&ceid=IN%3Aen (1331759) 130
# 3641 https://news.google.com/topics/topics/articles/topics/topics/articles/CAIiEB8C4PheRan5VNGuUswdWccqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen (1323685) 130
# 1378 https://news.google.com/articles/topics/topics/CAAqJAgKIh5DQkFTRUFvS0wyMHZNRFo2Y2pCbWJCSUNaVzRvQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1331721) 130
# 711 https://news.google.com/topics/articles/topics/articles/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNRE5tT0hkMEVnSmxiaWdBUAE?hl=en-IN&gl=IN&ceid=IN%3Aen (1323683) 130
# 740 https://news.google.com/topics/articles/articles/topics/articles/CAIiELw9zUULAS1jdMqf-yYiTvMqFwgEKg4IACoGCAoww7k_MMevCDC6rdgG?hl=en-IN&gl=IN&ceid=IN%3Aen (1331811) 130
# 2923 https://news.google.com/topics/articles/topics/publications/articles/articles/articles/CAIiEJpcxpTF6ROR7UH7-UthvKwqGQgEKhAIACoHCAow7pf_CjDdlfgCMP2F6gU?hl=en-IN&gl=IN&ceid=IN%3Aen (1323657) 130
# 3961 https://news.google.com/topics/articles/topics/publications/articles/articles/articles/articles/CAIiEOcIjNvslAoO6_4tze8yjpgqGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU?hl=en-IN&gl=IN&ceid=IN%3Aen (1323667) 130
# 3898 https://news.google.com/articles/topics/topics/articles/CAIiEBgKi9XJ4Fb4Yp9et04ObI4qFggEKg4IACoGCAoww7k_MMevCDDpywE?hl=en-IN&gl=IN&ceid=IN%3Aen (1323651) 130
# 3920 https://news.google.com/topics/articles/topics/articles/topics/stories/CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWpTaFBETGtZQU1FUkYtVXBkeWxFbUZLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1296448) 120
# 1718 https://news.google.com/topics/articles/topics/articles/articles/articles/publications/CAAqBwgKMJ2Yggsw2O_-Ag?hl=en-IN&gl=IN&ceid=IN%3Aen (1304512) 120
# 1905 https://news.google.com/topics/articles/topics/articles/articles/articles/publications/articles/CBMieGh0dHBzOi8vZmFjdGx5LmluL2ltYWdlLW9mLWNubi1yZXBvcnQtc3RhdGluZy12YWNjaW5lLWFkbWluaXN0ZXJlZC1jb3ZpZC0xOS1wYXRpZW50cy1lYXRpbmctb3RoZXJzLWlzLWRpZ2l0YWxseS1jcmVhdGVkL9IBAA?hl=en-IN&gl=IN&ceid=IN%3Aen (1296443) 120
# 1737 https://news.google.com/topics/articles/topics/articles/articles/articles/publications/CAAqBwgKMO6X_wow3ZX4Ag?hl=en-IN&gl=IN&ceid=IN%3Aen (1296474) 120
# 1256 https://news.google.com/topics/articles/topics/publications/articles/publications/CAAqBwgKMI_J_wowyK35Ag?hl=en-IN&gl=IN&ceid=IN%3Aen (1296440) 120
# 1227 https://news.google.com/topics/articles/articles/topics/articles/articles/CBMihQFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvZmFjdC1jaGVjay1wbS1tb2RpLW5ldmVyLXNhaWQtdmFqcGF5ZWUtc3RhcnRlZC10aGUtZmlyc3QtbWV0cm8taW4taW5kaWEtMTc1NDYwNC0yMDIwLTEyLTMw0gEA?hl=en-IN&gl=IN&ceid=IN%3Aen (1333657) 131
# 4368 https://news.google.com/topics/articles/articles/topics/articles/articles/articles/CAIiEKoPfz7z1mM4aUVNTI3N_ykqFwgEKg4IACoGCAowxLQ_MNevCDCyrdsG?hl=en-IN&gl=IN&ceid=IN%3Aen (1325562) 131
# 3123 https://news.google.com/topics/publications/publications/articles/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx1YlY4U0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1325561) 131
# 1758 https://news.google.com/topics/articles/topics/articles/articles/articles/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNREkwY1hKeUVnSmxiaWdBUAE?hl=en-IN&gl=IN&ceid=IN%3Aen (1333630) 131
# 370 https://news.google.com/topics/articles/articles/publications/CAAqBggKMMO5PzDHrwg?hl=en-IN&gl=IN&ceid=IN%3Aen (1333666) 131
# 3037 https://news.google.com/topics/articles/stories/CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWl4aGVUS2tZQU1FWmRvb1R4cGg3VXJLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1333608) 131
# 553 https://news.google.com/topics/topics/articles/CAIiEAx6XBamETd3L4rB_9mtwnwqGQgEKhAIACoHCAow5qqNCzD4q58DMMPepwY?hl=en-IN&gl=IN&ceid=IN%3Aen (1334289) 131
# 1614 https://news.google.com/topics/articles/topics/articles/articles/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE55YXpBU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1334316) 131
# 1189 https://news.google.com/topics/articles/articles/topics/articles/articles/CAIiEGSkLSkkLtjjC9k25Bza41oqGQgEKhAIACoHCAowj8n_CjDIrfkCMJWZ2AY?hl=en-IN&gl=IN&ceid=IN%3Aen (1334312) 131
# 2076 https://news.google.com/topics/articles/topics/articles/topics/topics/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRFp1ZEdvU0FtVnVHZ0pKVGlnQVAB?hl=en-IN&gl=IN&ceid=IN%3Aen (1334302) 131
# 2384 https://news.google.com/topics/publications/CAAiEPLaWn1TGx_bRcUvsOZFLA4qFAgKIhDy2lp9Uxsf20XFL7DmRSwO?hl=en-IN&gl=IN&ceid=IN%3Aen (1334332) 131
# 1433 https://news.google.com/topics/articles/topics/articles/topics/publications/articles/CAIiEOrBSYlHxSgnri6YuHv7JckqGQgEKhAIACoHCAowj8n_CjDIrfkCMNWczwY?hl=en-IN&gl=IN&ceid=IN%3Aen (1326224) 131
# 4817 https://news.google.com/topics/articles/topics/articles/articles/topics/publications/CAAqBwgKMMqPhwsw_rSFAw?hl=en-IN&gl=IN&ceid=IN%3Aen (1334335) 131
# 3455 https://news.google.com/articles/topics/publications/topics/CAAqHAgKIhZDQklTQ2pvSWJHOWpZV3hmZGpJb0FBUAE?hl=en-IN&gl=IN&ceid=IN%3Aen (1326227) 131
# 1996 https://news.google.com/topics/articles/articles/articles/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE55YXpBU0FtVnVLQUFQAQ?hl=en-IN&gl=IN&ceid=IN%3Aen (1326285) 131
# How many pages:
