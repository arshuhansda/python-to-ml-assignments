# %%
import numpy as np
import pandas as pd

# %%
draft = pd.read_csv('ex1.csv')
#draft = pd.read_csv(r'<full path>') #radded to when whole filepath 
#or double slash or add backslash instead of forward slash
#by default - first row is column names
#it will add a serial number column
    
 #Dataframe is a structured tablular form
draft
 #number of rows as input - default - first top 5 rows
 #last 5 rows from bottom
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft.head(2)
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
draft.tail(1)
# Out:
#    a   b   c   d message
# 2  9  10  11  12     foo

# %%
type(draft)
# Out:
# pandas.core.frame.DataFrame

# %%
draft2 = pd.read_table('test.tsv') #to read tab separated file

draft2
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
draft2.head()
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
draft3 = pd.read_csv('test.tsv') #to read tab separated file

draft3 ##doesnot give correct format data
# Out:
#               test\t test\ttest\ttest\ttest
# 0        sudh\tsudh\tsudh\tsudh\tsudh\tsudh
# 1  kumar\tkumar\tkumar\tkumar\tkumar\tkumar

# %%
draft4 = pd.read_csv('test.tsv',sep='\t') #to read tab separated file by adding separator

draft4 # give correct format data
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
pd.read_csv('ex1.csv',header=None) ##add first as a data row rather than column header
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
##Give your own column names
df = pd.read_csv('ex1.csv',names=['Col1','Col2','Message','Col3','Col4','Col5','Col6'])

df
# Out:
#   Col1 Col2 Message Col3     Col4  Col5  Col6
# 0    a    b       c    d  message   NaN   NaN
# 1    1    2       3    4    hello   NaN   NaN
# 2    5    6       7    8    world   NaN   NaN
# 3    9   10      11   12      foo   NaN   NaN

# %%
##Assigning columns start from right most side
df1 = pd.read_csv('ex1.csv',names=['Col1','Col2','Message'])
df1
# Out:
#      Col1 Col2  Message
# a b     c    d  message
# 1 2     3    4    hello
# 5 6     7    8    world
# 9 10   11   12      foo

# %%
parsed = pd.read_csv('csv_mindex.csv')

parsed
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
##change row indexes name
parsed = pd.read_csv('csv_mindex.csv',index_col=['key1','key2'])

##it will take of the dupliactes by merging
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
pd.read_csv('ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
##Remove junk if you know which rows are junk
pd.read_csv('ex4.csv',skiprows=[2,3])
# Out:
#              # hey!
# a b  c  d   message
# 1 2  3  4     hello
# 5 6  7  8     world
# 9 10 11 12      foo

# %%
result = pd.read_csv('ex5.csv')
result

#to show null values pandas shows NaN
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
##to change NaN to bool values, to check which values as null
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
##to know about any library just click on the keyword and do (shift+Tab)

# %%
result = pd.read_csv('ex5.csv',na_values=['NULL']) ##to trat any particular value as Null
#result = pd.read_csv('ex5.csv',na_values=['one'])
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
##Read an excel
draft4 = pd.read_excel('queen.xlsx') ##by default name is 0
draft4
# Out:
#                                               Column1          Column2  \
# 0   The generations indicate descent from George I...   1st generation
# 1   The generations indicate descent from George I...   2nd generation
# 2   The generations indicate descent from George I...   3rd generation
# 3   The generations indicate descent from George I...   4th generation
# 4   The generations indicate descent from George I...   5th generation
# 5   The generations indicate descent from George I...   6th generation
# 6   The generations indicate descent from George I...   7th generation
# 7   The generations indicate descent from George I...   8th generation
# 8   The generations indicate descent from George I...   9th generation
# 9   The generations indicate descent from George I...  10th generation
# 10  The generations indicate descent from George I...  11th generation
# 11  The generations indicate descent from George I...  12th generation
#
# ...

# %%
draft5 = pd.read_excel('queen.xlsx',sheet_name=3) ##by default name or sheet_number is 0
draft5.head(10)
# Out:
#                                   Column1          Column2  \
# 0  Queen of the United Kingdom (more ...)            Reign
# 1  Queen of the United Kingdom (more ...)       Coronation
# 2  Queen of the United Kingdom (more ...)      Predecessor
# 3  Queen of the United Kingdom (more ...)        Successor
# 4                        Empress of India            Reign
# 5                        Empress of India  Imperial Durbar
# 6                        Empress of India        Successor
# 7                        Empress of India             Born
# 8                        Empress of India             Died
# 9                        Empress of India           Burial
#
#                                              Column3
# 0                     20 June 1837 – 22 January 1901
# 1                                       28 June 1838
# 2                                         William IV
# 3                                         Edward VII
# ...

# %% [markdown]
# #### Panda - Assignment

# %%
ques = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

ques
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# #### 1. Some values in the the FlightNumber column are missing. These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Fill in these missing numbers and make the column an integer column (instead of a float column).

# %%
ques.dtypes
# Out:
# From_To          object
# FlightNumber    float64
# RecentDelays     object
# Airline          object
# dtype: object

# %%
ques.describe()
# Out:
#        FlightNumber
# count           3.0
# mean        10065.0
# std            20.0
# min         10045.0
# 25%         10055.0
# 50%         10065.0
# 75%         10075.0
# max         10085.0

# %%
ques
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
ques.columns
# Out:
# Index(['From_To', 'FlightNumber', 'RecentDelays', 'Airline'], dtype='object')

# %%
ques["FlightNumber"]
# Out:
# 0    10045.0
# 1        NaN
# 2    10065.0
# 3        NaN
# 4    10085.0
# Name: FlightNumber, dtype: float64

# %% [markdown]
# #### increase by 10 with each row

# %%
values = {'FlightNumber': ques['FlightNumber'].shift(1)+10}
ques.fillna(values, inplace=True)
ques
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# #### make the column an integer column (instead of a float column)

# %%
ques.astype({"FlightNumber":int})
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
ques.dtypes
# Out:
# From_To          object
# FlightNumber    float64
# RecentDelays     object
# Airline          object
# dtype: object

# %%
ques["FlightNumber"]
# Out:
# 0    10045.0
# 1    10055.0
# 2    10065.0
# 3    10075.0
# 4    10085.0
# Name: FlightNumber, dtype: float64

# %%
import numpy as np
ques = ques.astype({"FlightNumber":int})

# %%
ques["FlightNumber"]
# Out:
# 0    10045
# 1    10055
# 2    10065
# 3    10075
# 4    10085
# Name: FlightNumber, dtype: int32

# %%
ques
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# ### 2. The From_To column would be better as two separate columns! Split each string on the underscore delimiter _ to give a new temporary DataFrame with the correct values. Assign the correct column names to this temporary DataFrame.

# %%
ques
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
ques2 = ques.copy()
ques2
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
ques2[['From','To']] = ques2['From_To'].str.split('_',expand=True,)
ques2
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
ques
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
ques3 = ques.copy()
ques3[['From','To']] = ques3['From_To'].str.split('_',expand=True,)
ques3
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
column_headers = ['From','To','FlightNumber','RecentDelays','Airline','From_To']
ques3 = ques3.reindex(columns=column_headers)
ques3
# Out:
#        From         To  FlightNumber  RecentDelays              Airline  \
# 0    LoNDon      paris         10045      [23, 47]               KLM(!)
# 1    MAdrid      miLAN         10055            []    <Air France> (12)
# 2    londON  StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      PaRis         10075          [13]       12. Air France
# 4  Brussels     londOn         10085      [67, 32]          "Swiss Air"
#
#             From_To
# 0      LoNDon_paris
# 1      MAdrid_miLAN
# 2  londON_StockhOlm
# 3    Budapest_PaRis
# 4   Brussels_londOn

# %%
ques3 = ques3.drop(columns=['From_To'])
ques3
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    LoNDon      paris         10045      [23, 47]               KLM(!)
# 1    MAdrid      miLAN         10055            []    <Air France> (12)
# 2    londON  StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      PaRis         10075          [13]       12. Air France
# 4  Brussels     londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# ### 3. Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame. Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
ques4 = ques3.copy()
ques4
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    LoNDon      paris         10045      [23, 47]               KLM(!)
# 1    MAdrid      miLAN         10055            []    <Air France> (12)
# 2    londON  StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      PaRis         10075          [13]       12. Air France
# 4  Brussels     londOn         10085      [67, 32]          "Swiss Air"

# %%
type3 = ques4.apply(lambda x: x.dtype)
type3
# Out:
# From            object
# To              object
# FlightNumber     int32
# RecentDelays    object
# Airline         object
# dtype: object

# %%
ques4 = ques4.apply(lambda x: 1 if x.dtype == object)
# Out:
#   File "<ipython-input-222-8191c2b6c6a4>", line 1
#     ques4 = ques4.apply(lambda x: 1 if x.dtype == object)
#                                                         ^
# SyntaxError: invalid syntax

# %%
ques4['From']
# Out:
# 0      LoNDon
# 1      MAdrid
# 2      londON
# 3    Budapest
# 4    Brussels
# Name: From, dtype: object

# %%
type4 = ques4['From'].str.lower()
print(type4)
# Out:
# 0      london
# 1      madrid
# 2      london
# 3    budapest
# 4    brussels
# Name: From, dtype: object

# %%
ques4
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    LoNDon      paris         10045      [23, 47]               KLM(!)
# 1    MAdrid      miLAN         10055            []    <Air France> (12)
# 2    londON  StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      PaRis         10075          [13]       12. Air France
# 4  Brussels     londOn         10085      [67, 32]          "Swiss Air"

# %%
ques4['From'] = ques4['From'].str.lower().str.capitalize()

# %%
ques4
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      paris         10045      [23, 47]               KLM(!)
# 1    Madrid      miLAN         10055            []    <Air France> (12)
# 2    London  StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      PaRis         10075          [13]       12. Air France
# 4  Brussels     londOn         10085      [67, 32]          "Swiss Air"

# %%
ques4['To'] = ques4['To'].str.lower().str.capitalize()

# %%
ques4
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      Paris         10045      [23, 47]               KLM(!)
# 1    Madrid      Milan         10055            []    <Air France> (12)
# 2    London  Stockholm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris         10075          [13]       12. Air France
# 4  Brussels     London         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# ### 4. Delete the From_To column from df and attach the temporary DataFrame from the previous questions.

# %%
##Done

# %% [markdown]
# ### 5. In the RecentDelays column, the values have been entered into the DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value should be NaN. Expand the Series of lists into a DataFrame named delays, rename the columns delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df with delays.

# %%
ques5 = ques4.copy()
ques5
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      Paris         10045      [23, 47]               KLM(!)
# 1    Madrid      Milan         10055            []    <Air France> (12)
# 2    London  Stockholm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris         10075          [13]       12. Air France
# 4  Brussels     London         10085      [67, 32]          "Swiss Air"

# %%
length_of_list = ques5['RecentDelays'].str.len()
length_of_list
# Out:
# 0    2
# 1    0
# 2    3
# 3    1
# 4    2
# Name: RecentDelays, dtype: int64

# %% [markdown]
# #### pd.DataFrame(df2["teams"].to_list(), columns=['team1', 'team2'])
# ### Yields,
#
# #### team1 team2
# #### -------------
# #### 0    SF   NYG
# #### If you wanted to split a column of delimited strings rather than lists, you could similarly do:
#
# #### pd.DataFrame(df["teams"].str.split('<delim>', expand=True).values,columns=['team1', 'team2'])

# %%
#max_length = [length_of_list[2]][length_of_list[2].value() == length_of_list[2].max()]

length_of_list.max()
# Out:
# 3

# %%
#Create column names
columns_list =[]
for i in range(1,length_of_list.max()+1):
    columns_list.append("delay_"+str(i))

columns_list
# Out:
# ['delay_1', 'delay_2', 'delay_3']

# %%
ques5
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      Paris         10045      [23, 47]               KLM(!)
# 1    Madrid      Milan         10055            []    <Air France> (12)
# 2    London  Stockholm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris         10075          [13]       12. Air France
# 4  Brussels     London         10085      [67, 32]          "Swiss Air"

# %%
ques6 = pd.DataFrame(ques5['RecentDelays'].to_list(), columns=columns_list)

# %%
ques6
# Out:
#    delay_1  delay_2  delay_3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
con1 = ques5.drop(columns='RecentDelays')
con1
# Out:
#        From         To  FlightNumber              Airline
# 0    London      Paris         10045               KLM(!)
# 1    Madrid      Milan         10055    <Air France> (12)
# 2    London  Stockholm         10065  (British Airways. )
# 3  Budapest      Paris         10075       12. Air France
# 4  Brussels     London         10085          "Swiss Air"

# %%
result = pd.concat([con1,ques6],axis=1,join="outer")
result #completed
# Out:
#        From         To  FlightNumber              Airline  delay_1  delay_2  \
# 0    London      Paris         10045               KLM(!)     23.0     47.0
# 1    Madrid      Milan         10055    <Air France> (12)      NaN      NaN
# 2    London  Stockholm         10065  (British Airways. )     24.0     43.0
# 3  Budapest      Paris         10075       12. Air France     13.0      NaN
# 4  Brussels     London         10085          "Swiss Air"     67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN
